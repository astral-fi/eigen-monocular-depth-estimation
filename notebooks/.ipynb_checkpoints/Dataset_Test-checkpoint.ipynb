# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
sys.path.append(PROJECT_ROOT)

print("Added to path:", PROJECT_ROOT)
from models.dataset import Dataset
import matplotlib.pyplot as plt
# Out:
# Added to path: /home/ashutosh24135/eigen-monocular-depth

# %%
dataset = Dataset(
    root_dir="../data/",
    img_size=(224, 224)
)

print("Dataset size:", len(dataset))
print(dataset.img_dir)
# Out:
# Dataset size: 965
# ../data/images_paired

# %%
sample = dataset[0]

img = sample["image"]
depth = sample["depth"]
mask = sample["mask"]

print(img.shape, img.dtype)
print(depth.shape, depth.dtype)
print(mask.shape, mask.dtype)
# Out:
# ../data/depths_paired/2011_09_26_drive_0001_sync_0000000005.png
# torch.Size([3, 224, 224]) torch.float32
# torch.Size([1, 224, 224]) torch.float32
# torch.Size([1, 375, 1242]) torch.bool
